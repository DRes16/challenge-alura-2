# %% [markdown]
# <a href="https://colab.research.google.com/github/DRes16/challenge-alura-2/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
datos.head ()
# Out:
#                        {
# "nbformat": 4        NaN
# "nbformat_minor": 0  NaN
# "metadata": {        NaN
#   "colab": {         NaN
#     "provenance": [] NaN

# %%
datos = pd.read_csv('TelecomX_Data.json')

# %%
datos_ipynb = pd.read_csv('TelecomX_LATAM.ipynb')

# %%
# prompt: datos.head()

import pandas as pd
# Assuming TelecomX_Data.json is a CSV file and not a JSON file based on your read_csv attempt
# If it's actually a JSON file, you should use pd.read_json instead.
# Let's assume it's a CSV file for now.

# The previous lines already loaded and displayed the head of 'datos'.
# If you need to display it again:
# datos.head()

# It seems like you are trying to read an ipynb file as a CSV.
# An ipynb file is a notebook file and cannot be directly read as a CSV.
# If you intended to read data *from* the notebook, you would need to
# parse the notebook content, which is complex.
# If TelecomX_LATAM.ipynb is meant to be another CSV file, then correct the extension.

# Assuming you meant to read another CSV file named TelecomX_LATAM.csv
# If 'TelecomX_LATAM.ipynb' is indeed a CSV and named incorrectly, use:
# datos_latam = pd.read_csv('TelecomX_LATAM.ipynb') # Use this if it's a CSV with .ipynb extension

# If you meant to read a CSV named TelecomX_LATAM.csv, use:
# datos_latam = pd.read_csv('TelecomX_LATAM.csv')

# As the original code tried to read 'TelecomX_LATAM.ipynb' as a CSV,
# and that's likely incorrect unless it's a CSV with a wrong extension,
# I will keep the original line but add a comment about the potential issue.

# datos_ipynb = pd.read_csv('TelecomX_LATAM.ipynb') # Note: Reading an .ipynb as CSV is usually incorrect

# Let's re-display the head of the first dataframe as the prompt asked for `datos.head()`
print("Head of the 'datos' DataFrame:")
datos.head()
# Out:
# Head of the 'datos' DataFrame:
# Empty DataFrame
# ...

# %%
json_data.info(show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   customerID  7267 non-null   object
#  1   Churn       7267 non-null   object
#  2   customer    7267 non-null   object
#  3   phone       7267 non-null   object
#  4   internet    7267 non-null   object
#  5   account     7267 non-null   object
# dtypes: object(6)
# memory usage: 340.8+ KB

# %% [markdown]
# # Nueva sección

# %%
json_data.dtypes
# Out:
# customerID    object
# Churn         object
# customer      object
# phone         object
# internet      object
# account       object
# dtype: object

# %%
import pandas
pandas.options.display.max_info_columns
# Out:
# 100

# %%
pd.unique(json_data['customer'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-32-6a2acb05b843> in <cell line: 0>()
# ----> 1 pd.unique(json_data['customer'])
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/algorithms.py in unique(values)
#     399     array([('a', 'b'), ('b', 'a'), ('a', 'c')], dtype=object)
#     400     """
# --> 401     return unique_with_mask(values)
#     402
#     403
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/algorithms.py in unique_with_mask(values, mask)
#     438     table = hashtable(len(values))
#     439     if mask is None:
# --> 440         uniques = table.unique(values)
#     441         uniques = _reconstruct_data(uniques, original.dtype, original)
#     442         return uniques
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.unique()
#
# ...

# %%
pandas.Series.dt.normalize( json_data['customer'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-36-59f0038979b2> in <cell line: 0>()
# ----> 1 pandas.Series.dt.normalize( json_data['customer'])
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/accessor.py in f(self, *args, **kwargs)
#     110         def _create_delegator_method(name: str):
#     111             def f(self, *args, **kwargs):
# --> 112                 return self._delegate_method(name, *args, **kwargs)
#     113
#     114             f.__name__ = name
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#    6300
#    6301     @final
#
# AttributeError: 'Series' object has no attribute '_delegate_method'

# %% [markdown]
# # Task
# Convert the JSON data from "TelecomX_Data.json" to CSV format.

# %% [markdown]
# ## Load json data
#
# ### Subtask:
# Read the `TelecomX_Data.json` file using `pd.read_json`.

# %% [markdown]
# **Reasoning**:
# The previous attempts to read the data as CSV failed because the file is in JSON format. The subtask requires reading the JSON file using `pd.read_json`.

# %%
json_data = pd.read_json('TelecomX_Data.json')

# %% [markdown]
# **Reasoning**:
# The subtask is to read the JSON file into a DataFrame, which was accomplished in the previous step. The next step is to verify the data was loaded correctly by displaying the first few rows.

# %%
json_data.head()

# %%
# prompt: Mediante el marco de datos json_data: gender

import pandas as pd
# Normalize the 'customer' column which contains nested JSON data
customer_df = pd.json_normalize(json_data['customer'])
# Display the first 5 rows of the normalized customer data
customer_df.head()

# %% [markdown]
# ## Normalize nested data
#
# ### Subtask:
# The JSON data appears to have nested structures. I will use `pd.json_normalize` to flatten the nested data into a DataFrame.

# %% [markdown]
# **Reasoning**:
# Flatten the nested JSON data using `pd.json_normalize` and display the head of the resulting DataFrame to verify the structure.

# %%
df_normalized = pd.json_normalize(json_data.to_dict(orient='records'))
display(df_normalized.head())

# %% [markdown]
# ## Save as csv
#
# ### Subtask:
# Save the normalized DataFrame to a new CSV file.

# %% [markdown]
# **Reasoning**:
# Save the normalized DataFrame to a CSV file without the index.

# %%
df_normalized.to_csv('TelecomX_Normalized.csv', index=False)

# %% [markdown]
# ## Verify conversion
#
# ### Subtask:
# Load the saved CSV file to ensure the conversion was successful and display the head of the new DataFrame.

# %% [markdown]
# **Reasoning**:
# Load the newly created CSV file into a DataFrame and display its head to verify the conversion.

# %%
df_from_csv = pd.read_csv('TelecomX_Normalized.csv')
display(df_from_csv.head())

# %% [markdown]
# ## Summary:
#
# ### Data Analysis Key Findings
#
# *   The JSON data from "TelecomX\_Data.json" was successfully loaded into a pandas DataFrame.
# *   The nested structure of the JSON data was successfully flattened using `pd.json_normalize`, creating a DataFrame with columns representing the nested fields.
# *   The normalized DataFrame was successfully saved to a CSV file named "TelecomX\_Normalized.csv" without including the DataFrame index.
# *   The saved CSV file was successfully loaded back into a DataFrame, confirming the successful conversion process.
#
# ### Insights or Next Steps
#
# *   The flattened CSV file is now ready for further data analysis or modeling tasks.
# *   Consider exploring the data in the "TelecomX\_Normalized.csv" file to identify patterns or insights related to customer churn.

# %%
df_normalized = pd.json_normalize(json_data.to_dict(orient='records'))
display(df_normalized.head())
# Out:
#    customerID Churn customer.gender  customer.SeniorCitizen customer.Partner  \
# 0  0002-ORFBO    No          Female                       0              Yes
# 1  0003-MKNFE    No            Male                       0               No
# 2  0004-TLHLJ   Yes            Male                       0               No
# 3  0011-IGKFF   Yes            Male                       1              Yes
# 4  0013-EXCHZ   Yes          Female                       1              Yes
#
#   customer.Dependents  customer.tenure phone.PhoneService phone.MultipleLines  \
# 0                 Yes                9                Yes                  No
# 1                  No                9                Yes                 Yes
# 2                  No                4                Yes                  No
# 3                  No               13                Yes                  No
# 4                  No                3                Yes                  No
#
# ...

# %%
df_normalized.to_csv('TelecomX_Normalized.csv', index=False)

# %%
df_from_csv = pd.read_csv('TelecomX_Normalized.csv')
display(df_from_csv.head())
# Out:
#    customerID Churn customer.gender  customer.SeniorCitizen customer.Partner  \
# 0  0002-ORFBO    No          Female                       0              Yes
# 1  0003-MKNFE    No            Male                       0               No
# 2  0004-TLHLJ   Yes            Male                       0               No
# 3  0011-IGKFF   Yes            Male                       1              Yes
# 4  0013-EXCHZ   Yes          Female                       1              Yes
#
#   customer.Dependents  customer.tenure phone.PhoneService phone.MultipleLines  \
# 0                 Yes                9                Yes                  No
# 1                  No                9                Yes                 Yes
# 2                  No                4                Yes                  No
# 3                  No               13                Yes                  No
# 4                  No                3                Yes                  No
#
# ...
